# %%
# reading a file
file = open("deerwalk.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# hello I am from deerwalk

# %%
# reading a fle
file = open("deerwalk.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello I am from deerwalk

# %%
# reading a file
file = open("deerwalk.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# hello I am from deerwalk

# %%
# writing a file
file = open("data.txt", "w")
file.write("hello")
file.close()
